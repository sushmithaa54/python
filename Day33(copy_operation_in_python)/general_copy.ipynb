# %%
list1=[10,20,30,40]
list2=list1
print(list1)
print()
print(list2)
# Out:
# [10, 20, 30, 40]
#
# [10, 20, 30, 40]

# %%
list1=[10,20,30,40]
list2=list1
print(id(list1))
print()
print(id(list2))
# Out:
# 2150579247616
#
# 2150579247616

# %%
# modification of elements in copied object
list1=[10,20,30,40]
list2=list1
list2[3]=98
print(list1)
print()
print(list2)
# Out:
# [10, 20, 30, 98]
#
# [10, 20, 30, 98]
