# %%
def outer():
    num=98
    def inner():
        num=num+2
        print(num)
    inner()
outer()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[2], line 7
#       5         print(num)
#       6     inner()
# ----> 7 outer()
#
# Cell In[2], line 6, in outer()
#       4     num=num+2
#       5     print(num)
# ----> 6 inner()
#
# Cell In[2], line 4, in outer.<locals>.inner()
#       3 def inner():
# ----> 4     num=num+2
#       5     print(num)
#
# UnboundLocalError: cannot access local variable 'num' where it is not associated with a value

# %%
def outer():
    num=98
    def inner():
        nonlocal num
        num=num+2
        print(num)
    inner()
outer()
# Out:
# 100
