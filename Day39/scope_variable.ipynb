# %%
# global variable
num=98
def diaplay():
    print(f'inside function:{num}')
diaplay()
print(f'outside function:{num}')
# Out:
# inside function:98
# outside function:98

# %%
num1=100
num2=200
def addition():
    result=num1+num2
    print(result)
addition()
outside=num1+num2
print(outside)
# Out:
# 300
# 300

# %%
# modify global variable
# n=98
# def diaplay():
#     n=n+3
#     print(num)
# diaplay()

n=98
def diaplay():
    global n
    n=n+3
    print(num)
diaplay()
# Out:
# 98

# %%
# local variable
def display():
    n1=45
    print(n1)
diaplay()
# Out:
# 98

# %%
# def display():
#     n=45
# diaplay()
# print(n)
# Out:
# 98
# 116

# %%
# accesing local variable using outside function by using global key word
def display():
    global num
    num=45
diaplay()
print(num)
# Out:
# 98
# 98
