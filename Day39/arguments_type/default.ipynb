# %%
def display(ename,sal=9000):
    print(f'{ename} and {sal}')
display('smith')
# Out:
# smith and 9000

# %%
def display(ename,sal=9000):
    print(f'{ename} and {sal}')
display('smith',sal=98000)
# Out:
# smith and 98000
