# %%
#WAP  to create class as employee and access employee name,salay and designation using object ,using class variables
class employee:
    ename='smith'
    sal=98000
    job='analyst'
e1=employee()
print(f'employee name:{e1.ename},salary:{e1.sal} and designation :{e1.job}')
# Out:
# employee name:smith,salary:98000 and designation :analyst

# %%
#WAP to display student informations using class variables
class student:
    sname='suhas'
    phno=1234567890
    email='suhas@gmail.com'
    sub1='SQL'
    sub2='PYTHOn'
    sub3='WEB'
s=student()
print(f'sudent information:-\nname:{s.sname}\nphone number:{s.phno}\nemail id:{s.email}\nsubject1:{s.sub1}\nsubject2:{s.sub2}\nsubject3:{s.sub3}')
# Out:
# sudent information:-
# name:suhas
# phone number:1234567890
# email id:suhas@gmail.com
# subject1:SQL
# subject2:PYTHOn
# subject3:WEB

# %%
# WAP to display multiple object informations using object variable
class employeee:
    pass
e1=employee()
e1.empno=10
e1.ename='smith'

e2=employee()
e2.empno=20
e2.ename='king'

print(f'employee1 name:{e1.ename} and deptno:{e1.empno}')
print(f'employee2 name:{e2.ename} and deptno:{e2.empno}')
# Out:
# employee1 name:smith and deptno:10
# employee2 name:king and deptno:20

# %%
# WAP to display car properties using object variables
class car:
    pass
c1=car()
c1.name='BMW'
c1.color='pink'

c2=car()
c2.name='tesla'
c2.color='black'

c3=car()
c3.name='scorpio'
c3.color='white'

print(f'car name:{c1.name} and color:{c1.color}')
print(f'car name:{c2.name} and color:{c2.color}')
print(f'car name:{c3.name} and color:{c3.color}')
# Out:
# car name:BMW and color:pink
# car name:tesla and color:black
# car name:scorpio and color:white
