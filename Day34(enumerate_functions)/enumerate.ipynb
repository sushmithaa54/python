# %%
string='python'
for index,ch in enumerate(string):
    print(index,ch)
# Out:
# 0 p
# 1 y
# 2 t
# 3 h
# 4 o
# 5 n

# %%
# 1) wap to find position of 3rd occurance of charecter a
s='basavanagudi'
count=0
for i,ch in enumerate(s):
    if ch=='a':
        count=count+1
        if count==3:
            print(i)
            break
# Out:
# 5

# %%
string='python'
for index,ch in enumerate(string,start=1):
    print(index,ch)
# Out:
# 1 p
# 2 y
# 3 t
# 4 h
# 5 o
# 6 n

# %%
string='python'
print(string.index('j'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 string='python'
# ----> 2 print(string.index('j'))
#
# ValueError: substring not found
