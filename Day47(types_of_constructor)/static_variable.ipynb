# %%
class employee:
    c_name='BTS'
    def __init__(self,ename,job):
        self.ename=ename
        self.job=job
    def display(self):
        print(f'employee name:{self.ename}, job:{self.job} and company name:{employee.c_name}')
d1=employee('nitya','fassion designer')
d1.display()
d2=employee('manthan','photographer')
d2.display()
# Out:
# employee name:nitya, job:fassion designer and company name:BTS
# employee name:manthan, job:photographer and company name:BTS
