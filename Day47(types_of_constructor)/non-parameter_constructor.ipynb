# %%
class employee:
    def __init__(self):
        pass
    def display(self):
        print(f'employee name:{self.ename} and salary:{self.sal}')
e1=employee()
e1.ename='smith'
e1.sal=30000
e1.display()
# Out:
# employee name:smith and salary:30000

# %%
class subject:
    def __init__(self):
        pass
    def display(self):
        print(f'subject 1 : {self.sub1} and subject 2 : {self.sub2}')
e1=subject()
e1.sub1='python'
e1.sub2='jaava'
e1.display()
# Out:
# subject 1 : python and subject 2 : jaava
