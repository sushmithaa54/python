# %%
# display 'hello python' using user defined functions
def msg():
    print('hello python')
msg()
# Out:
# hello python

# %%
# print 1,2,3 numbers
def numbers():
    print('1')
    print('2')
    print('3')
numbers()
# Out:
# 1
# 2
# 3
