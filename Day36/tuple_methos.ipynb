# %%
# 1) COUNT METHOD
t1=(10,20,30,30,70)
print(t1.count(30))
# Out:
# 2

# %%
# 2) INDEX METHOD
t1=(10,20,30,30,70)
print(t1.index(30))

# t1=(10,20,30,30,70)
# print(t1.index(90))


# Q) wapt find position of 3rd occurance of specified element(using enumerate function)
t1=(10,20,30,40,50,60,90,30,30,20)
count=0
element=30
for i,ch in enumerate(t1):
    if ch==element:
        count=count+1
        if count==3:
            print(i)
            break
# Out:
# 2
# 8
