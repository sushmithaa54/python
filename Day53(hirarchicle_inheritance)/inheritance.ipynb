# %%
# 1
class vehicle:
    def start(self):
        print('vehicle starts')
        
class car(vehicle):
    def car_start(self):
        print('driving class')
        
class bike(vehicle):
    def bike_start(self):
        print('riding bike')

c=car()
b=bike()
c.start()
c.car_start()

b.start()
b.bike_start()
# Out:
# vehicle starts
# driving class
# vehicle starts
# riding bike

# %%
# 2
class employee:
    def work(self):
        print('employee works')
class manager(employee):
    def manage(self):
        print('manager manage the team')
class developer(employee):
    def code(self):
        print('developer will develop the application')
class testing(employee):
    def test(self):
        print('tester test the application')
        
m=manager()
m.work()
m.manage()

d=developer()
d.work()
d.code()

t=testing()
t.work()
t.test()
# Out:
# employee works
# manager manage the team
# employee works
# developer will develop the application
# employee works
# tester test the application

# %%
# 3
class banckaccount:
    def __init__(self,cname,acctno,balance):
        self.cname=cname
        self.acctno=acctno
        self.balance=balance
        
    def display(self):
        print(f'customer name:{self.cname}\n account number:{self.acctno}\n balance is:{self.balance}')
        return self
    
    def deposite(self,amount):
        self.balance+=amount
        print(f'{amount} has been deposited')
        print(f'updated balance is :{self.balance}')
        return self
    
    def withdraw(self,amount):
        if amount<=self.balance:
            self.balance-=amount
            print(f'{amount} has been withdrawn')
            print(f'updated balance is:{self.balance}')
            
        else:
            print('insufficient balance')

class savingsbanckaccount(banckaccount):
    def __init__(self, cname, acctno, balance):
        super().__init__(cname, acctno, balance)
    
    def account_info(self):
        print('savings bank customer details')
        return self
    
class currentbankaccount(banckaccount):
    def __init__(self, cname, acctno, balance):
        super().__init__(cname, acctno, balance)
        
    def account_info(self):
        print('current bank customer details')
        return self

s1=savingsbanckaccount('smith',1234,95000)
s1.account_info().display().deposite(1000).withdraw(500)

print()

c1=currentbankaccount('martin',9845,98000)
c1.account_info().display().deposite(2000).withdraw(1000)
# Out:
# savings bank customer details
# customer name:smith
#  account number:1234
#  balance is:95000
# 1000 has been deposited
# updated balance is :96000
# 500 has been withdrawn
# updated balance is:95500
#
# current bank customer details
# customer name:martin
#  account number:9845
#  balance is:98000
# 2000 has been deposited
# updated balance is :100000
# 1000 has been withdrawn
# updated balance is:99000

# %%
# 4
class employee:
    def get_bonus(self,salary):
        self.salary=salary
        print(f'employee salary is :{self.salary}')
        print(f'employee bonus is:{self.salary*0.10}')
class developer(employee):
    def get_bonus(self, salary):
       self.salary=salary
       print(f'developer bonus is :{self.salary*0.30}')
class manager(employee):
    def get_bonus(self, salary):
        self.salary=salary
        print(f'manager bonus is:{self.salary*0.60}')
d1=developer()
m1=manager()
d1.get_bonus(65000)
m1.get_bonus(75000)
# Out:
# developer bonus is :19500.0
# manager bonus is:45000.0

# %%
# 5
class BankAccount:
    def __init__(self,cname,balance):
        self.cname=cname
        self.balance=balance
    def deposit(self,amount):
        if amount<=0:
            raise ValueError('Amount should be greater than zero')
        self.balance+=amount
        print(f'{amount} deposited.Updated balance : {self.balance}')
    def withdraw(self,amount):
        if amount>self.balance:
            raise ValueError("Insufficient balance")
        self.balance-=amount
        print(f'{amount} withdrawn.Updated balance : {self.balance}')
    def display(self):
        print(f'Account Holder : {self.cname}')
        print(f'Total balance : {self.balance}')
class SavingBankAccount(BankAccount):
    def __init__(self, cname, balance):
        super().__init__(cname, balance)
    def withdraw(self,amount):
        if amount>10000:
            raise ValueError('Max withdraw limit is 10000')
        super().withdraw(amount)
class SalaryAccount(BankAccount):
    def __init__(self, cname, balance,acctno):
        super().__init__(cname, balance)
        self.acctno=acctno
    def deposit(self,amount):
        if amount<20000:
            raise ValueError('Salary should be more than 20,000')
        super().deposit(amount)
c1=SavingBankAccount('smith',30000)
c2=SalaryAccount('Allen',40000,12345)
print('Saving Account Transactions')
try:
    c1.deposit(20000)
    c1.withdraw(30000)
    c1.display()
except ValueError as e:
    print("Error:",e)
print('Salary Account Transactions')
try:
    c2.deposit(2000)
    c2.withdraw(10000)
    c2.display()
except ValueError as e:
    print('Error :',e)
# Out:
# Saving Account Transactions
# 20000 deposited.Updated balance : 50000
# Error: Max withdraw limit is 10000
# Salary Account Transactions
# Error : Salary should be more than 20,000
