# %%
while True:
    print('hello')
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
a=5
while a:
    print('hello')

# %%
a=1
while a<5:
    print('hello')
    a=a+1
# Out:
# hello
# hello
# hello
# hello

# %%
num=10
while num>5:
    print('hello')
    num=num-1
# Out:
# hello
# hello
# hello
# hello
# hello

# %%
#good evening for 10 times
a=1
while a<=10:
    print('good evening')
    a+=1
# Out:
# good evening
# good evening
# good evening
# good evening
# good evening
# good evening
# good evening
# good evening
# good evening
# good evening

# %%
#series of numbers 1 to 6
a=1
while a<=6:
    print(a)
    a+=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#alphabets from A to K
ch='A'
while ch<='K':
    print(ch)
    ch=chr(ord(ch)+1)
# Out:
# A
# B
# C
# D
# E
# F
# G
# H
# I
# J
# K

# %%
#odd numbers from 1 to 5
a=1
while a<=5:
    if a%2!=0:
        print(a)
    a+=1
# Out:
# 1
# 3
# 5

# %%
n=1
while n<=13:
    if n%3==0 and n%4==0:
        print(n)
    n+=1
# Out:
# 12
