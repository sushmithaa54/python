# %%
# 1) Print sequence from 0 to 5
i = 0
while i <= 5:
    print(i)
    i = i + 1
else:
    print("program completed")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# program completed

# %%
# 2) Print "Hello python" 3 times
i = 0
while i < 3:
    print("Hello python")
    i = i + 1
# Out:
# Hello python
# Hello python
# Hello python

# %%
# 3) Print numbers from 6 to 0
i = 6
while i >= 0:
    print(i, end=' ')
    i = i - 1
# Out:
# 6 5 4 3 2 1 0

# %%
# 4) Print even numbers from 1 to 10
i = 1
while i <= 10:
    if i % 2 == 0:
        print(i)
    i = i + 1
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
# 5) Print even numbers from 1 to 10 (without if)
i = 2
while i <= 10:
    print(i, end=' ')
    i = i + 2
# Out:
# 2 4 6 8 10

# %%
# 6) Print odd numbers from 1 to 10
i = 1
while i <= 10:
    if i % 2 != 0:
        print(i, end=' ')
    i = i + 1
# Out:
# 1 3 5 7 9

# %%
# 7) Print odd numbers from 1 to 10 (without if)
i = 1
while i <= 10:
    print(i)
    i = i + 2
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# 8) Print table of given number
num = 2
i = 1

while i <= 10:
    print(f"{num} * {i} = {num*i}")
    i = i + 1
# Out:
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20

# %%
# 9) Sum of first 5 natural numbers
i = 1
total = 0

while i <= 5:
    total = total + i
    i = i + 1

print(total)
# Out:
# 15

# %%
# 10) Sum of even numbers from 1 to 10
i = 1
total = 0

while i <= 10:
    if i % 2 == 0:
        total = total + i
    i = i + 1

print(total)
# Out:
# 30

# %%
# 11) Sum of odd numbers from 1 to 10
i = 1
total = 0

while i <= 10:
    if i % 2 != 0:
        total = total + i
    i = i + 1

print(total)
# Out:
# 25

# %%
# 12) Sum of even and odd numbers from 1 to 10
i = 1
even_total = 0
odd_total = 0

while i <= 10:
    if i % 2 == 0:
        even_total = even_total + i
    else:
        odd_total = odd_total + i
    i = i + 1

print(f"sum of even numbers is : {even_total}")
print(f"sum of odd numbers is : {odd_total}")
# Out:
# sum of even numbers is : 30
# sum of odd numbers is : 25

# %%
# 13) Product of even numbers from 1 to 20
i = 1
prod = 1

while i <= 20:
    if i % 2 == 0:
        prod = prod * i
    i = i + 1

print(prod)
# Out:
# 3715891200

# %%
# 14) Product of odd numbers from 1 to 20
i = 1
prod = 1

while i <= 20:
    if i % 2 != 0:
        prod = prod * i
    i = i + 1

print(prod)
# Out:
# 654729075

# %%
# 15) Sum and product of even and odd numbers
i = 1

even_sum = 0
odd_sum = 0
even_prod = 1
odd_prod = 1

while i <= 10:
    if i % 2 == 0:
        even_sum = even_sum + i
        even_prod = even_prod * i
    else:
        odd_sum = odd_sum + i
        odd_prod = odd_prod * i
    i = i + 1

print(f"sum of even numbers : {even_sum}")
print(f"sum of odd numbers : {odd_sum}")
print(f"product of even numbers : {even_prod}")
print(f"product of odd numbers : {odd_prod}")
# Out:
# sum of even numbers : 30
# sum of odd numbers : 25
# product of even numbers : 3840
# product of odd numbers : 945

# %%
# 16) Count number of digits
i = 7956
count = 0

while i > 0:
    count = count + 1
    i = i // 10

print(count)
# Out:
# 4

# %%
# 17) Print numbers from 15 to 21
n = 15

while n <= 21:
    print(n)
    n = n + 1
# Out:
# 15
# 16
# 17
# 18
# 19
# 20
# 21
