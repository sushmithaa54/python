# %%
# to write the data
file=open('python1.txt','w')
content=file.write('writting a data')
file.close()

# %%
# to read the data
file=open('python1.txt','r')
display=file.read()
print(display)
file.close()
# Out:
# writting a data

# %%
# to append the data
file=open('python1.txt','a')
content=file.write('\nthis is the first line')
file.close()
