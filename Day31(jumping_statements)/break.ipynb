# %%
# 1 wap to print no.s from 1 to 4 using 1 to 20 range
for i in range (1,21):
    if i==5:
        break
    print(i,end=" ")
# Out:
# 1 2 3 4

# %%
# 2 wap to print charecters upto alphabet 'e
for i in 'abcdfgegrvb':
    if i=='e':
        break
    print(i,end=" ")
# Out:
# a b c d f g

# %%
# 3 wap to stop loop when number divisible by 7 in 1 to 20 range
for num in range(1,21):
    if num%7==0:
        break
    print(num,end=" ")
# Out:
# 1 2 3 4 5 6
